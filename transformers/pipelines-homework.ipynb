# %%
# !pip install -r ../requirements.txt
# Out:
# DEPRECATION: Loading egg at /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages/huggingface_hub-0.19.4-py3.8.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: torch>=2.1.2 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: transformers in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (4.30.2)
# Collecting ffmpeg (from -r ../requirements.txt (line 3))
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ffmpeg-python (from -r ../requirements.txt (line 4))
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: timm in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (0.9.12)
# Requirement already satisfied: datasets in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: evaluate in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: scikit-learn in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: pandas in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 9)) (2.1.4)
# Collecting peft (from -r ../requirements.txt (line 10))
#   Downloading peft-0.7.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: accelerate in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (0.25.0)
# Collecting autoawq (from -r ../requirements.txt (line 12))
#   Downloading autoawq-0.1.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting optimum (from -r ../requirements.txt (line 13))
#   Downloading optimum-1.16.1-py3-none-any.whl.metadata (17 kB)
# Collecting auto-gptq (from -r ../requirements.txt (line 14))
#   Downloading auto_gptq-0.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting bitsandbytes>0.39.0 (from -r ../requirements.txt (line 15))
#   Downloading bitsandbytes-0.41.3.post2-py3-none-any.whl.metadata (9.8 kB)
# Collecting jiwer (from -r ../requirements.txt (line 16))
#   Downloading jiwer-3.0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting soundfile>=0.12.1 (from -r ../requirements.txt (line 17))
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.4 MB/s eta 0:00:00a 0:00:01
# Collecting librosa (from -r ../requirements.txt (line 18))
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: sympy in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: fsspec in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torch>=2.1.2->-r ../requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.2->-r ../requirements.txt (line 1)) (12.3.101)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages/huggingface_hub-0.19.4-py3.8.egg (from transformers->-r ../requirements.txt (line 2)) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (2023.10.3)
# Requirement already satisfied: requests in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from transformers->-r ../requirements.txt (line 2)) (4.65.0)
# Collecting future (from ffmpeg-python->-r ../requirements.txt (line 4))
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 10.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from timm->-r ../requirements.txt (line 5)) (0.16.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (0.3.7)
# Requirement already satisfied: xxhash in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: multiprocess in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (0.70.15)
# Requirement already satisfied: aiohttp in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from datasets->-r ../requirements.txt (line 6)) (3.9.0)
# Requirement already satisfied: responses<0.19 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from evaluate->-r ../requirements.txt (line 7)) (0.18.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 9)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from pandas->-r ../requirements.txt (line 9)) (2023.3)
# Requirement already satisfied: psutil in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from peft->-r ../requirements.txt (line 10)) (5.9.5)
# Collecting transformers (from -r ../requirements.txt (line 2))
#   Downloading transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from autoawq->-r ../requirements.txt (line 12)) (0.1.99)
# Collecting lm-eval (from autoawq->-r ../requirements.txt (line 12))
#   Downloading lm_eval-0.4.0.tar.gz (457 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.1/457.1 kB 9.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting texttable (from autoawq->-r ../requirements.txt (line 12))
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: toml in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from autoawq->-r ../requirements.txt (line 12)) (0.10.2)
# Collecting attributedict (from autoawq->-r ../requirements.txt (line 12))
#   Downloading attributedict-0.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: protobuf in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from autoawq->-r ../requirements.txt (line 12)) (4.25.1)
# Collecting tabulate (from autoawq->-r ../requirements.txt (line 12))
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting tokenizers>=0.12.1 (from autoawq->-r ../requirements.txt (line 12))
#   Downloading tokenizers-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting coloredlogs (from optimum->-r ../requirements.txt (line 13))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# Collecting rouge (from auto-gptq->-r ../requirements.txt (line 14))
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq->-r ../requirements.txt (line 14))
#   Downloading gekko-1.0.6-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 11.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from jiwer->-r ../requirements.txt (line 16)) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer->-r ../requirements.txt (line 16))
#   Downloading rapidfuzz-3.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: cffi>=1.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->-r ../requirements.txt (line 17)) (1.15.1)
# Collecting audioread>=2.1.9 (from librosa->-r ../requirements.txt (line 18))
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: decorator>=4.3.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from librosa->-r ../requirements.txt (line 18)) (5.1.1)
# Collecting numba>=0.51.0 (from librosa->-r ../requirements.txt (line 18))
#   Downloading numba-0.58.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting pooch>=1.0 (from librosa->-r ../requirements.txt (line 18))
#   Downloading pooch-1.8.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting soxr>=0.3.2 (from librosa->-r ../requirements.txt (line 18))
#   Downloading soxr-0.3.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting lazy-loader>=0.1 (from librosa->-r ../requirements.txt (line 18))
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting msgpack>=1.0 (from librosa->-r ../requirements.txt (line 18))
#   Downloading msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: pycparser in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->-r ../requirements.txt (line 17)) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->-r ../requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->-r ../requirements.txt (line 6)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->-r ../requirements.txt (line 6)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->-r ../requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->-r ../requirements.txt (line 6)) (1.2.0)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.51.0->librosa->-r ../requirements.txt (line 18))
#   Downloading llvmlite-0.41.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa->-r ../requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: six>=1.5 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from requests->transformers->-r ../requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from requests->transformers->-r ../requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from requests->transformers->-r ../requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from requests->transformers->-r ../requirements.txt (line 2)) (2023.11.17)
# Collecting rootpath>=0.1.0 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading rootpath-0.1.1-py3-none-any.whl (15 kB)
# Collecting inspecta>=0.1.0 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading inspecta-0.1.3-py3-none-any.whl (9.2 kB)
# Collecting colour-runner>=0.0.5 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading colour_runner-0.1.1-py2.py3-none-any.whl (3.7 kB)
# Collecting deepdiff>=3.3.0 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading deepdiff-6.7.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting tox>=3.0.0 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading tox-4.11.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting coverage>=4.5.2 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading coverage-7.4.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting codecov>=2.0.15 (from attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading codecov-2.1.13-py2.py3-none-any.whl (16 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum->-r ../requirements.txt (line 13))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from jinja2->torch>=2.1.2->-r ../requirements.txt (line 1)) (2.1.3)
# Collecting jsonlines (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numexpr in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from lm-eval->autoawq->-r ../requirements.txt (line 12)) (2.8.7)
# Collecting pybind11>=2.6.2 (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading pybind11-2.11.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting pytablewriter (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading pytablewriter-1.2.0-py3-none-any.whl.metadata (37 kB)
# Collecting rouge-score>=0.0.4 (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading sacrebleu-2.4.0-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.2 MB/s eta 0:00:00
# Collecting sqlitedict (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tqdm-multiprocess (from lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: zstandard in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from lm-eval->autoawq->-r ../requirements.txt (line 12)) (0.19.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from sympy->torch>=2.1.2->-r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from torchvision->timm->-r ../requirements.txt (line 5)) (10.1.0)
# Collecting blessings (from colour-runner>=0.0.5->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: pygments in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from colour-runner>=0.0.5->attributedict->autoawq->-r ../requirements.txt (line 12)) (2.17.2)
# Collecting ordered-set<4.2.0,>=4.0.2 (from deepdiff>=3.3.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting termcolor>=1.1.0 (from inspecta>=0.1.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting absl-py (from rouge-score>=0.0.4->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting nltk (from rouge-score>=0.0.4->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.2 MB/s eta 0:00:0000:0100:01
# Collecting portalocker (from sacrebleu>=1.5.0->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: colorama in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from sacrebleu>=1.5.0->lm-eval->autoawq->-r ../requirements.txt (line 12)) (0.4.6)
# Collecting lxml (from sacrebleu>=1.5.0->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading lxml-5.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: cachetools>=5.3.1 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12)) (5.3.2)
# Collecting chardet>=5.2 (from tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pluggy>=1.3 (from tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyproject-api>=1.6.1 (from tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading pyproject_api-1.6.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting virtualenv>=20.24.3 (from tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading virtualenv-20.25.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12)) (68.0.0)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading pathvalidate-3.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading tcolorpy-0.1.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval->autoawq->-r ../requirements.txt (line 12))
#   Downloading typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.24.3->tox>=3.0.0->attributedict->autoawq->-r ../requirements.txt (line 12))
#   Downloading distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Downloading peft-0.7.1-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 7.9 MB/s eta 0:00:00
# Downloading autoawq-0.1.8-cp311-cp311-manylinux2014_x86_64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 11.2 MB/s eta 0:00:0000:0100:01
# Downloading optimum-1.16.1-py3-none-any.whl (403 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.3/403.3 kB 9.5 MB/s eta 0:00:00:00:01
# Downloading auto_gptq-0.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 11.3 MB/s eta 0:00:0000:0100:01
# Downloading bitsandbytes-0.41.3.post2-py3-none-any.whl (92.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 8.8 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading msgpack-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.0/558.0 kB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading numba-0.58.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 11.3 MB/s eta 0:00:0000:0100:01
# Downloading pooch-1.8.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.7 MB/s eta 0:00:00
# Downloading rapidfuzz-3.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Downloading soxr-0.3.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading coverage-7.4.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.1/237.1 kB 8.4 MB/s eta 0:00:00
# Downloading deepdiff-6.7.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 5.3 MB/s eta 0:00:00
# Downloading llvmlite-0.41.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 8.4 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 6.3 MB/s eta 0:00:00
# Downloading tox-4.11.4-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.0/154.0 kB 7.3 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 5.3 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 9.2 MB/s eta 0:00:00
# Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Downloading pyproject_api-1.6.1-py3-none-any.whl (12 kB)
# Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Downloading virtualenv-20.25.0-py3-none-any.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.5 MB/s eta 0:00:00
# Downloading lxml-5.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 11.5 MB/s eta 0:00:0000:0100:01
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 9.2 MB/s eta 0:00:00ta 0:00:01
# Building wheels for collected packages: ffmpeg, future, lm-eval, rouge-score, sqlitedict
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=0b437efb64896894cd00c3e7430a4d14736b10a1b95fdfd92f7c72137acfdf41
#   Stored in directory: /home/ivanzhu/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492024 sha256=bd630611086c0d3f14196f5940f697304af4f2351d5a38caabd7b4abb15ae5d6
#   Stored in directory: /home/ivanzhu/.cache/pip/wheels/da/19/ca/9d8c44cd311a955509d7e13da3f0bea42400c469ef825b580b
#   Building wheel for lm-eval (pyproject.toml) ... done
#   Created wheel for lm-eval: filename=lm_eval-0.4.0-py3-none-any.whl size=994996 sha256=f22f31b2b319601443d53fc984ad1fdd9ade0f83ceeb7bf71707ba3b019eea81
#   Stored in directory: /home/ivanzhu/.cache/pip/wheels/c0/0c/4a/43c6bc9f3ad182a3fcd95a3a1607f6138f98905e1c5e3dcaaf
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24932 sha256=088f64c7f7f321997883e7715871fbe98ab78aa0b91bf23a6961aa16f674a81f
#   Stored in directory: /home/ivanzhu/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=a9cfc9911e9c150a957a0b21e76ef61ce24047766473349c58c7386d5bda184b
#   Stored in directory: /home/ivanzhu/.cache/pip/wheels/73/63/89/7210274f9b7fb033b8f22671f64c0e0b55083d30c3c046a3ff
# Successfully built ffmpeg future lm-eval rouge-score sqlitedict
# Installing collected packages: texttable, sqlitedict, ffmpeg, distlib, bitsandbytes, virtualenv, tqdm-multiprocess, termcolor, tcolorpy, tabulate, soxr, rouge, rapidfuzz, pyproject-api, pybind11, portalocker, pluggy, pathvalidate, ordered-set, nltk, msgpack, lxml, llvmlite, lazy-loader, jsonlines, humanfriendly, gekko, future, coverage, chardet, blessings, audioread, absl-py, tox, soundfile, sacrebleu, rouge-score, pooch, numba, mbstrdecoder, jiwer, ffmpeg-python, deepdiff, colour-runner, coloredlogs, codecov, typepy, tokenizers, rootpath, librosa, transformers, inspecta, peft, DataProperty, attributedict, tabledata, optimum, auto-gptq, pytablewriter, lm-eval, autoawq
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Uninstalling pluggy-1.0.0:
#       Successfully uninstalled pluggy-1.0.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
# Successfully installed DataProperty-1.0.1 absl-py-2.0.0 attributedict-0.3.0 audioread-3.0.1 auto-gptq-0.6.0 autoawq-0.1.8 bitsandbytes-0.41.3.post2 blessings-1.7 chardet-5.2.0 codecov-2.1.13 coloredlogs-15.0.1 colour-runner-0.1.1 coverage-7.4.0 deepdiff-6.7.1 distlib-0.3.8 ffmpeg-1.4 ffmpeg-python-0.2.0 future-0.18.3 gekko-1.0.6 humanfriendly-10.0 inspecta-0.1.3 jiwer-3.0.3 jsonlines-4.0.0 lazy-loader-0.3 librosa-0.10.1 llvmlite-0.41.1 lm-eval-0.4.0 lxml-5.0.0 mbstrdecoder-1.1.3 msgpack-1.0.7 nltk-3.8.1 numba-0.58.1 optimum-1.16.1 ordered-set-4.1.0 pathvalidate-3.2.0 peft-0.7.1 pluggy-1.3.0 pooch-1.8.0 portalocker-2.8.2 pybind11-2.11.1 pyproject-api-1.6.1 pytablewriter-1.2.0 rapidfuzz-3.6.1 rootpath-0.1.1 rouge-1.0.1 rouge-score-0.1.2 sacrebleu-2.4.0 soundfile-0.12.1 soxr-0.3.7 sqlitedict-2.1.0 tabledata-1.3.3 tabulate-0.9.0 tcolorpy-0.1.4 termcolor-2.4.0 texttable-1.7.0 tokenizers-0.15.0 tox-4.11.4 tqdm-multiprocess-0.0.11 transformers-4.36.2 typepy-1.3.2 virtualenv-20.25.0

# %%
from transformers import pipeline

# 图生文
pipe = pipeline("image-to-text")
# Out:
# No model was supplied, defaulted to ydshieh/vit-gpt2-coco-en and revision 65636df (https://huggingface.co/ydshieh/vit-gpt2-coco-en).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 100%|██████████| 4.34k/4.34k [00:00<00:00, 50.0MB/s]
# pytorch_model.bin: 100%|██████████| 982M/982M [01:37<00:00, 10.0MB/s]
# tokenizer_config.json: 100%|██████████| 236/236 [00:00<00:00, 3.88MB/s]
# vocab.json: 100%|██████████| 798k/798k [00:00<00:00, 893kB/s]
# merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 695kB/s]
# tokenizer.json: 100%|██████████| 1.36M/1.36M [00:01<00:00, 1.30MB/s]
# special_tokens_map.json: 100%|██████████| 120/120 [00:00<00:00, 2.14MB/s]
# preprocessor_config.json: 100%|██████████| 211/211 [00:00<00:00, 3.54MB/s]
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
pipe("http://images.cocodataset.org/val2017/000000039769.jpg")
# Out:
# /home/ivanzhu/tools/miniconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1355: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# [{'generated_text': 'a cat laying on a blanket next to a cat laying on a bed '}]
